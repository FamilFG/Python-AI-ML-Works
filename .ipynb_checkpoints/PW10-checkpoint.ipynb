# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import shapiro, probplot, norm

# %%
def load_txt(path):
    return np.loadtxt(path, delimiter=',')

# %%
def analyze(data, name):
    print(name, "mean =", np.mean(data))
    print(name, "std =", np.std(data))
    print(name, "Shapiro =", shapiro(data))
    plt.hist(data, bins=20)
    plt.title(name)
    plt.show()
    probplot(data, dist="norm", plot=plt)
    plt.title(name)
    plt.show()

# %%
X = np.random.normal(1, 2, 1000)
Y = np.random.uniform(-1, 1, 1000)
Z = np.random.exponential(5, 1000)

# %%
analyze(X, "X")
analyze(Y, "Y")
analyze(Z, "Z")
# Out:
# X normal mean = 1.018567745223368
# X normal std = 1.981212908504575
# X normal Shapiro = ShapiroResult(statistic=np.float64(0.9989410938601114), pvalue=np.float64(0.8412824849212437))
# Y uniform mean = -0.004394999862693709
# Y uniform std = 0.5750255383806654
# Y uniform Shapiro = ShapiroResult(statistic=np.float64(0.9547649469521925), pvalue=np.float64(5.28031317446412e-17))
# Z exponential mean = 4.902994763142781
# Z exponential std = 4.971312054873719
# Z exponential Shapiro = ShapiroResult(statistic=np.float64(0.811072896462982), pvalue=np.float64(1.2368104248882498e-32))

# %%
ph = load_csv("pH.txt")
spinningTop = load_csv("spinningTop.txt")
wind = load_csv("wind.txt")
cosmic = load_csv("cosmicParticle.txt")

# %%
analyze(ph, "pH")
analyze(spinningTop, "spinningTop")
analyze(wind, "wind")
analyze(cosmic, "cosmic")
# Out:
# pH mean = 4.764833333333334
# pH std = 0.21034488874755727
# pH Shapiro = ShapiroResult(statistic=np.float64(0.9881865449028746), pvalue=np.float64(0.8301440572191361))
# spinningTop mean = 177.47
# spinningTop std = 104.85146207850417
# spinningTop Shapiro = ShapiroResult(statistic=np.float64(0.9516531962347481), pvalue=np.float64(0.0010677386459093576))
# wind mean = 40.76
# wind std = 19.58731879390966
# wind Shapiro = ShapiroResult(statistic=np.float64(0.9922632303960973), pvalue=np.float64(0.05508487574670824))
# cosmic mean = 4949.465306122449
# cosmic std = 3197.2252797719248
# cosmic Shapiro = ShapiroResult(statistic=np.float64(0.9403653628882518), pvalue=np.float64(1.9779270906664826e-08))
