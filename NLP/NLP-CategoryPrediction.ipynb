# %%
import pandas as pd
from sklearn.pipeline import Pipeline, FunctionTransformer
import numpy as np 
from sklearn.feature_extraction.text import TfidfVectorizer
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_excel('azeri_news.xlsx')

# %%
df
# Out:
#            Category                                              Title  \
# 0           Maraqlı     Naviforce Sport Saat 2016 ilə zövqlərin ahəngi
# 1           Maraqlı  Sinir ,oynaq , sinir bel ağrılarına 3 gündə son !
# 2           Maraqlı            Dəyərindən qat-qat aşağı qiymətə Mənzil
# 3             İdman  2024 və 2028-ci il olimpiadalarının keçiriləcə...
# 4             Dünya                                 Türkiyədə zəlzələ
# ...             ...                                                ...
# 49995       Siyasət  Əli Kərimli terrorçularla da əməkdaşlığa hazır...
# 49996       Siyasət  Elşən Musayev: “Bəlkə elə o terrorist Əli Kəri...
# 49997         Dünya    İstanbulda 52 mərtəbəli binada yanğın baş verib
# 49998         Dünya  “Onlar cinayətkarlardır və bir-bir məhv edilir...
# 49999  İqtisadiyyat  Ukrayna Mərkəzi Bankı gözlənilmədən uçot dərəc...
#
#                                             News_Article
# 0      Naviforce Sport Saat 2016 Yapon Mexanizmi Yapo...
# 1      ŞOK ! ŞOK ! ŞOK ! Xanımlar və bəylər , bel və ...
# 2      Dəyərindən qat-qat Aşağı Qiymətə. Həzi Aslanov...
# 3       2028-ci il Yay Olimpiya və Paralimpiya Oyunla...
# 4       Türkiyədə daha bir zəlzələ meydana gəlib.   L...
# ...                                                  ...
# 49995    AXCP sədri "Milli Şura"nın mitinqində qəsdən...
# 49996    "Ümumiyyətlə, Milli Şuraya xoş olan, hətta o...
# 49997    Türkiyənin İstanbul şəhərinin Ataşehir rayon...
# 49998    Rusiyanı tərk edərək İŞİD sıralarında döyüşə...
# 49999   Ukrayna Mərkəzi Bankı (NBU) bu gün keçirdiyi ...
#
# [50000 rows x 3 columns]

# %%
df.Category.unique()
# Out:
# array(['Maraqlı', 'İdman', 'Dünya', 'Siyasət', 'İqtisadiyyat',
#        'Mədəniyyət'], dtype=object)

# %%
def clean_text(text):
    az_letters = set('əöüşçğıƏÖÜŞÇĞI')
    
    text = ''.join(
        char.lower() if (char.isalpha() and char.isascii()) or char in az_letters else ' ' 
        for char in text
    )
    
    return re.sub(r' +', ' ', text).strip()

# %%
df['text'] = df['Title'] + ' ' + df['News_Article']
df['text'] = df['text'].apply(clean_text)

# %%
az_stopwords = [
    "a", "ad", "əgər", "amma", "ancaq", "artıq", "asılı", "az", "bax", "belə", "beləliklə",
    "bəli", "bəzən", "bəzi", "bütün", "bu", "buna", "bunda", "bundan", "bunu", "bunun",
    "burada", "bura", "bəri", "cəmi", "çox", "çünki",
    "da", "də", "daha", "demək", "deyil", "deyə", "dərhal", "dünən",
    "elə", "edir", "edən", "edərək", "edəcək", "edilir", "edilən", "edib", "et", "etdi", "etmək",
    "ə", "əldə", "əhəmiyyət", "əks", "əksinə", "əlaqədar", "ən", "etibarilə",
    "faktiki", "görə", "habelə", "hansı", "harada", "hara", "harda", "hazırda", "hə", "həmin",
    "hər", "hərçənd", "hələ", "heç", "heçbir", "heçbiri", "heçdə", "heçmi", "həm", "həmçinin",
    "xeyli", "xeyr", "xüsusilə",
    "içində", "ilə", "indi", "isə",
    "kifayət", "kimi", "kim", "kimin", "kimə", "kimdən", "kimdə", "kimdənsə", "kimisə", "kiminsə",
    "lakin",
    "məhz", "mən", "mənim", "mənə", "məndə", "məndən", "məni",
    "sən", "sənin", "sənə", "səndə", "səndən", "səni",
    "o", "onun", "ona", "onda", "ondan", "onu",
    "biz", "bizim", "bizə", "bizdə", "bizdən", "bizi",
    "siz", "sizin", "sizə", "sizdə", "sizdən", "sizi",
    "onlar", "onların", "onlara", "onlarda", "onlardan", "onları",
    "məncə", "səncə", "fikrincə",
    "məsələn", "məs", "məsəl", "müəyyən", "mütləq",
    "nə", "nəhayət", "nəinki", "nə qədər", "nə üçün", "nə zaman", "nə vaxt",
    "nədir", "nədən", "nədə", "nəyə", "nəni", "nəsə",
    "necə", "neçənci", "neçə", "neçəsi", "neçəsinin",
    "olaraq", "olur", "oldu", "olmuş", "olacaq", "olan", "olduğu", "olduğunu", "olsa", "olsun",
    "ona görə", "ona gör",
    "özü", "öz", "özüm", "özün", "özümdən", "özündən", "özündən", "özünə", "özününkülər",
    "qədər", "qarşı", "qəti", "qismən",
    "sanki", "sonra", "sonradan", "son", "sonuncu", "sualtı",
    "şübhəsiz",
    "təki", "təkcə", "tutaq", "tam", "tamamilə",
    "u", "üçün", "üstəlik",
    "və", "və ya", "və yaxud", "yaxud", "ya", "ya da",
    "yenə", "yenə də", "yəni", "yaxşı", "yox", "yoxsa",
    "zaman", "zamanı", 'bəlkə'
]

# %%
def remove_stopwords(text, remove_stopwords=True):
      
    if remove_stopwords:
        stopwords_set = set(az_stopwords)
        
        words = text.split()
        filtered_words = [word for word in words if word not in stopwords_set and len(word) > 3]
        text = " ".join(filtered_words)
        return text
    return text

# %%
df['text'] = df['text'].apply(remove_stopwords)

# %%
df
# Out:
#            Category                                              Title  \
# 0           Maraqlı     Naviforce Sport Saat 2016 ilə zövqlərin ahəngi
# 1           Maraqlı  Sinir ,oynaq , sinir bel ağrılarına 3 gündə son !
# 2           Maraqlı            Dəyərindən qat-qat aşağı qiymətə Mənzil
# 3             İdman  2024 və 2028-ci il olimpiadalarının keçiriləcə...
# 4             Dünya                                 Türkiyədə zəlzələ
# ...             ...                                                ...
# 49995       Siyasət  Əli Kərimli terrorçularla da əməkdaşlığa hazır...
# 49996       Siyasət  Elşən Musayev: “Bəlkə elə o terrorist Əli Kəri...
# 49997         Dünya    İstanbulda 52 mərtəbəli binada yanğın baş verib
# 49998         Dünya  “Onlar cinayətkarlardır və bir-bir məhv edilir...
# 49999  İqtisadiyyat  Ukrayna Mərkəzi Bankı gözlənilmədən uçot dərəc...
#
#                                             News_Article  \
# 0      Naviforce Sport Saat 2016 Yapon Mexanizmi Yapo...
# 1      ŞOK ! ŞOK ! ŞOK ! Xanımlar və bəylər , bel və ...
# 2      Dəyərindən qat-qat Aşağı Qiymətə. Həzi Aslanov...
# 3       2028-ci il Yay Olimpiya və Paralimpiya Oyunla...
# 4       Türkiyədə daha bir zəlzələ meydana gəlib.   L...
# ...                                                  ...
# 49995    AXCP sədri "Milli Şura"nın mitinqində qəsdən...
# 49996    "Ümumiyyətlə, Milli Şuraya xoş olan, hətta o...
# 49997    Türkiyənin İstanbul şəhərinin Ataşehir rayon...
# 49998    Rusiyanı tərk edərək İŞİD sıralarında döyüşə...
# 49999   Ukrayna Mərkəzi Bankı (NBU) bu gün keçirdiyi ...
#
#                                                     text
# 0      naviforce sport saat zövqlərin ahəngi naviforc...
# 1      sinir oynaq sinir ağrılarına gündə xanımlar bə...
# 2      dəyərindən aşağı qiymətə mənzil dəyərindən aşa...
# 3      olimpiadalarının keçiriləcəyi şəhərlər müəyyən...
# 4      türkiyədə zəlzələ türkiyədə zəlzələ meydana gə...
# ...                                                  ...
# 49995  kərimli terrorçularla əməkdaşlığa hazırdır axc...
# 49996  elşən musayev terrorist kərimlinin adamıdır üm...
# 49997  stanbulda mərtəbəli binada yanğın verib türkiy...
# 49998  cinayətkarlardır məhv edilirlər peskov rusiyan...
# 49999  ukrayna mərkəzi bankı gözlənilmədən uçot dərəc...
#
# [50000 rows x 4 columns]

# %%
X = df['text']
y = df['Category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 2000, random_state=42)

vectorizer = CountVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train)

# %%
X_train_vectorized
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 4257805 stored elements and shape (48000, 216120)>

# %%
def swap_dict(dictionary):
    return {value: key for key, value in dictionary.items()}

# %%
new_vocab_dict = swap_dict(vectorizer.vocabulary_)

# %%
new_vocab_dict
# Out:
# {119431: 'paris',
#  189488: 'yaxınlığında',
#  11050: 'avtomobil',
#  141371: 'restorana',
#  202030: 'çırpılıb',
#  187927: 'yaralı',
#  53573: 'fransanın',
#  210725: 'şəhərinin',
#  94933: 'markalı',
#  98788: 'minik',
#  11056: 'avtomobili',
#  98314: 'milli',
#  168572: 'trend',
#  74149: 'istinadən',
#  20720: 'bildirir',
#  62800: 'hadisə',
#  113834: 'nəticəsində',
#  191121: 'yaşlı',
#  177947: 'uşaq',
#  68257: 'həlak',
#  115509: 'olub',
#  113359: 'nəfər',
#  186061: 'xəsarət',
#  4281: 'alıb',
#  106226: 'məlumata',
#  214491: 'əsasən',
#  2765: 'alanların',
#  182938: 'vəziyyəti',
#  14520: 'ağırdır',
#  11065: 'avtomobilin',
#  158615: 'sürücüsü',
#  147695: 'saxlanılıb',
#  131800: 'qidalar',
#  79061: 'karlığın',
#  129458: 'qarşısını',
#  4433: 'alır',
#  186667: 'yahi',
#  191068: 'yaşlandıqca',
#  104337: 'müxtəlif',
#  159855: 'səbəblərdən',
#  50232: 'eşitməmizdə',
#  109443: 'narahatlıqlar',
#  188049: 'yaranır',
#  131806: 'qidalarla',
#  50225: 'eşitmədə',
#  187966: 'yarana',
#  21407: 'biləcək',
#  124814: 'problemlərin',
#  3637: 'almaq',
#  103174: 'mümkündür',
#  1849: 'ailem',
#  131809: 'qidaların',
#  152489: 'siyahısını',
#  37817: 'diqqətinizə',
#  199565: 'çatdırır',
#  123783: 'potasium',
#  127850: 'qandakı',
#  27444: 'bədən',
#  167894: 'toxumasındakı',
#  95849: 'maye',
#  98994: 'miqdarının',
#  173233: 'tənzimlənməsindən',
#  29446: 'cavabdehdir',
#  50216: 'eşitmə',
#  148453: 'sağlamlığınız',
#  212061: 'əhəmiyyətli',
#  21487: 'bilər',
#  34203: 'daxili',
#  134851: 'qulaqdakı',
#  134884: 'qulağın',
#  40643: 'duyduğumuz',
#  162042: 'səsləri',
#  46550: 'elektrik',
#  178963: 'vasitəsilə',
#  20149: 'beyinə',
#  205134: 'ötürən',
#  198255: 'zəngin',
#  130182: 'qaynağına',
#  18416: 'bağlıdır',
#  171055: 'təbii',
#  162203: 'səviyyələr',
#  12800: 'azalır',
#  191064: 'yaşla',
#  18412: 'bağlı',
#  75063: 'itkisinə',
#  159812: 'səbəb',
#  50602: 'faktor',
#  17705: 'baxımından',
#  79218: 'kartof',
#  73750: 'ispanaq',
#  91621: 'lobya',
#  123379: 'pomidor',
#  135563: 'quru',
#  207116: 'üzüm',
#  130191: 'qaysı',
#  16264: 'banan',
#  133425: 'qovun',
#  123612: 'portağal',
#  129879: 'qatıq',
#  169571: 'turşusu',
#  116555: 'orqanizmdəki',
#  191748: 'yeni',
#  67278: 'hüceyrə',
#  26783: 'böyümə',
#  126554: 'qabiliyətinə',
#  44083: 'dəstək',
#  180310: 'verən',
#  86087: 'kritik',
#  46654: 'elementdir',
#  7345: 'araşdırmalar',
#  169576: 'turşusunun',
#  75061: 'itkisini',
#  12758: 'azaltdığını',
#  59044: 'göstərir',
#  41234: 'dövran',
#  170531: 'tüklü',
#  67295: 'hüceyrələrin',
#  148469: 'sağlıqlı',
#  41997: 'düzgün',
#  210787: 'şəkildə',
#  76360: 'işləməsini',
#  172755: 'təmin',
#  206260: 'ünsürdür',
#  29724: 'cciyər',
#  26651: 'böyrək',
#  206394: 'ürək',
#  145355: 'sair',
#  74811: 'itburnu',
#  94479: 'maqnezium',
#  99584: 'miçiqan',
#  176358: 'universitetində',
#  6611: 'aparılan',
#  44290: 'dəstəyi',
#  2747: 'alan',
#  211384: 'şəxslərin',
#  181186: 'vitamini',
#  21939: 'birlikdə',
#  57640: 'gurultuyla',
#  132975: 'qoruduğunu',
#  58935: 'göstərib',
#  770: 'adamları',
#  94483: 'maqneziumun',
#  195099: 'yüksək',
#  162039: 'səslər',
#  159250: 'sırasında',
#  189787: 'yayılan',
#  161281: 'sərbəst',
#  138967: 'radikalların',
#  174391: 'təsirlərini',
#  133089: 'qoruyan',
#  16877: 'baryer',
#  147414: 'savaşdığını',
#  157895: 'söyləyir',
#  12071: 'ayrıca',
#  134850: 'qulaqda',
#  192856: 'yetərli',
#  115232: 'olmaması',
#  33047: 'damarlarının',
#  82392: 'kiçilməsinə',
#  108956: 'nahiyədə',
#  114711: 'oksigenin',
#  193931: 'yoxluğuna',
#  94482: 'maqneziumla',
#  213659: 'ənginar',
#  151909: 'sink',
#  116563: 'orqanizmin',
#  71154: 'immunitet',
#  152283: 'sistemini',
#  60142: 'gücləndirir',
#  49935: 'eyni',
#  196194: 'zamanda',
#  26795: 'böyüməsi',
#  148337: 'sağalmalara',
#  154405: 'soyuqdəymədə',
#  69169: 'hətta',
#  151878: 'sinir',
#  124006: 'pozucu',
#  134831: 'qulaq',
#  72024: 'infeksiyalarına',
#  98101: 'mikrobları',
#  49115: 'etməkdə',
#  188136: 'yararlıdır',
#  211379: 'şəxslərdə',
#  30451: 'cingildəməsinin',
#  102179: 'müalicəsində',
#  174351: 'təsirli',
#  6033: 'antibiotik',
#  151035: 'sidik',
#  133393: 'qovucu',
#  43841: 'dərmanlarla',
#  174400: 'təsirə',
#  56929: 'girdiyi',
#  74033: 'istifadədən',
#  215214: 'əvvəl',
#  68249: 'həkimə',
#  103578: 'müraciət',
#  45382: 'edin',
#  151914: 'sinklə',
#  168116: 'toyuq',
#  54344: 'fıstıq',
#  15386: 'badam',
#  107280: 'mərcimək',
#  170626: 'tünd',
#  209460: 'şokolad',
#  96559: 'meksikada',
#  138615: 'qətlə',
#  192515: 'yetirilib',
#  96569: 'meksikanın',
#  125729: 'puebla',
#  209755: 'ştatındakı',
#  175956: 'uitsilan',
#  149296: 'serdan',
#  27700: 'bələdiyyə',
#  1235: 'administrasiyasının',
#  143789: 'rəhbəri',
#  109246: 'naməlum',
#  211376: 'şəxslər',
#  174080: 'tərəfindən',
#  112124: 'novosti',
#  179586: 'verdiyi',
#  185701: 'xəbərə',
#  160009: 'sədri',
#  94372: 'manuel',
#  48162: 'ernandes',
#  120196: 'pasyon',
#  11066: 'avtomobilində',
#  60449: 'güllələnərək',
#  131593: 'qeyd',
#  45584: 'edək',
#  191035: 'yaşayış',
#  106921: 'məntəqəsinin',
#  143800: 'rəhbərinin',
#  192541: 'yetirilməsi',
#  21826: 'birinci',
#  1527: 'affa',
#  143224: 'rusiya',
#  53965: 'futbol',
#  169028: 'ttifaqına',
#  48981: 'etiraz',
#  106054: 'məktubu',
#  57839: 'göndərib',
#  9296: 'assosiasiyanın',
#  110925: 'nformasiya',
#  31246: 'ctimaiyyətlə',
#  212400: 'əlaqələr',
#  35912: 'departamentinin',
#  143934: 'rəisi',
#  98032: 'mikayıl',
#  113609: 'nərimanoğlunun',
#  141114: 'report',
#  144333: 'rəsmi',
#  91252: 'liqasının',
#  107410: 'mərkəz',
#  197267: 'zonasında',
#  180803: 'viii',
#  169519: 'turun',
#  7228: 'ararat',
#  143386: 'ryazan',
#  118284: 'oyunu',
#  34672: 'dağlıq',
#  128318: 'qarabağdakı',
#  149194: 'separatçı',
#  140707: 'rejimin',
#  17935: 'bayrağ',
#  207419: 'ının',
#  112982: 'nümayiş',
#  48616: 'etdirilməsi',
#  20693: 'bildirilib',
#  113608: 'nərimanoğlu',
#  36381: 'deyib',
#  106026: 'məktubda',
#  50575: 'fakt',
#  122198: 'pislənilib',
#  50585: 'faktla',
#  171468: 'tədbir',
#  58342: 'görülməsi',
#  183273: 'xahiş',
#  115736: 'olunub',
#  48081: 'ermənilərə',
#  108275: 'məxsus',
#  83505: 'komandanın',
#  50780: 'fanatları',
#  118205: 'oyun',
#  168658: 'tribunada',
#  48112: 'ermənistan',
#  132741: 'qondarma',
#  135780: 'qurumun',
#  17930: 'bayraqlarını',
#  187097: 'yanaşı',
#  9472: 'asıblar',
#  63034: 'halbuki',
#  175852: 'uefa',
#  104913: 'müəyyənləşdirdiyi',
#  130020: 'qaydalara',
#  118249: 'oyunlar',
#  163464: 'tanınmamış',
#  141320: 'respublikaların',
#  17931: 'bayraqlarının',
#  155056: 'stadionlara',
#  80728: 'keçirilməsi',
#  126707: 'qadağandır',
#  5984: 'antalyaspor',
#  112866: 'növbəti',
#  168321: 'transferini',
#  140268: 'reallaşdırmaq',
#  206969: 'üzrədir',
#  170750: 'türkiyənin',
#  82803: 'klubu',
#  65521: 'heyətini',
#  54012: 'futbolçu',
#  60115: 'gücləndirib',
#  57356: 'goal',
#  185596: 'xəbər',
#  179863: 'verir',
#  5979: 'antalya',
#  142495: 'roma',
#  53569: 'fransalı',
#  54063: 'futbolçusu',
#  180968: 'vilyam',
#  179474: 'venkeri',
#  65523: 'heyətinə',
#  31988: 'cəlb',
#  156828: 'superliqa',
#  173030: 'təmsilçisi',
#  70804: 'illik',
#  103445: 'müqavilə',
#  71453: 'imzalayacaq',
#  179473: 'venker',
#  79336: 'karyerası',
#  214226: 'ərzində',
#  109334: 'nantes',
#  37369: 'dinamo',
#  100494: 'moskva',
#  155159: 'standard',
#  82792: 'klubların',
#  211297: 'şərəfni',
#  133098: 'qoruyub',
#  70684: 'ildən',
#  29003: 'canavarlar',
#  207036: 'üzvü',
#  34536: 'dayaq',
#  188639: 'yarımmüdafiəçisi',
#  205163: 'ötən',
#  102075: 'mövsümü',
#  69647: 'icarə',
#  214483: 'əsasında',
#  95116: 'marseille',
#  82820: 'klubunda',
#  80664: 'keçirib',
#  116392: 'ordumuz',
#  151281: 'silahlardan',
#  10274: 'atəş',
#  13415: 'açdı',
#  172461: 'təlimdən',
#  58506: 'görüntülər',
#  13170: 'azərbaycan',
#  124471: 'prezidenti',
#  151299: 'silahlı',
#  136385: 'qüvvələrin',
#  83502: 'komandanı',
#  90714: 'lham',
#  212776: 'əliyevin',
#  174220: 'təsdiq',
#  48784: 'etdiyi',
#  122491: 'plana',
#  80764: 'keçirilən',
#  55850: 'genişmiqyaslı',
#  172484: 'təlimlərin',
#  41465: 'döyüş',
#  10256: 'atışlı',
#  214356: 'əsas',
#  107355: 'mərhələsi',
#  69761: 'icra',
#  100676: 'movqe',
#  102442: 'müdafiə',
#  110042: 'nazirliyinin',
#  108092: 'mətbuat',
#  184489: 'xidmətinə',
#  104198: 'müvafiq',
#  107327: 'mərhələdə',
#  7965: 'artilleriya',
#  63965: 'hava',
#  67360: 'hücumundan',
#  178938: 'vasitələri',
#  10668: 'aviasiya',
#  46960: 'eləcədə',
#  37012: 'digər',
#  22090: 'birləşmələr',
#  151208: 'silah',
#  165943: 'texnikanın',
#  174622: 'tətbiqi',
#  172420: 'təlim',
#  164043: 'tapşırıqlarını',
#  192164: 'yerinə',
#  192506: 'yetiriblər',
#  180557: 'video',
#  58511: 'görüntüləri',
#  173371: 'təqdim',
#  45412: 'edirik',
#  145949: 'salyanda',
#  166418: 'tikintisinə',
#  98560: 'milyon',
#  94085: 'manat',
#  12192: 'ayrılıb',
#  212750: 'əliyev',
#  145947: 'salyan',
#  139867: 'rayonunun',
#  128577: 'qaraçala',
#  42210: 'düzənlik',
#  121486: 'peyk',
#  178767: 'varlı',
#  193456: 'yolunun',
#  166412: 'tikintisi',
#  171491: 'tədbirlər',
#  63596: 'haqqında',
#  161820: 'sərəncam',
#  71467: 'imzalayıb',
#  106332: 'məlumatına',
#  211878: 'əhalinin',
#  190699: 'yaşadığı',
#  106920: 'məntəqəsini',
#  22061: 'birləşdirən',
#  107118: 'məqsədi',
#  41146: 'dövlət',
#  26912: 'büdcəsinin',
#  214452: 'əsaslı',
#  182543: 'vəsait',
#  133848: 'qoyuluşu',
#  185943: 'xərclərinin',
#  26338: 'bölgüsündə',
#  193393: 'yollarının',
#  191768: 'yenidən',
#  135656: 'qurulması',
#  114014: 'nəzərdə',
#  169860: 'tutulmuş',
#  182550: 'vəsaitin',
#  94103: 'manatı',
#  13138: 'azəravtoyol',
#  13658: 'açıq',
#  160393: 'səhmdar',
#  32088: 'cəmiyyətinə',
#  93781: 'maliyyə',
#  110045: 'nazirliyinə',
#  105048: 'məbləğdə',
#  93847: 'maliyyələşməni',
#  164030: 'tapşırılıb',
#  37086: 'diktatora',
#  139309: 'raket',
#  159063: 'sınaqları',
#  80681: 'keçirildi',
#  53250: 'foto',
#  208862: 'şimali',
#  85070: 'koreya',
#  183391: 'xalq',
#  35671: 'demokratik',
#  141343: 'respublikasındakı',
#  37085: 'diktator',
#  11802: 'ayda',
#  43080: 'dəfə',
#  131955: 'qitələrarası',
#  16093: 'ballistik',
#  80881: 'keçirməsinə',
#  29439: 'cavab',
#  32241: 'cənubi',
#  159068: 'sınaqlarını',
#  56118: 'gerçəkləşdiriblər',
#  8974: 'asiaone',
#  139330: 'raketlər',
#  85088: 'koreyanın',
#  213879: 'ərazi',
#  156599: 'sularına',
#  25752: 'buraxılıb',
#  159058: 'sınaqlarda',
#  73969: 'istehsalı',
#  67006: 'hyunmoo',
#  139340: 'raketlərindən',
#  9581: 'atacms',
#  7754: 'army',
#  162484: 'tactical',
#  99343: 'missile',
#  157497: 'system',
#  116131: 'operativ',
#  162641: 'taktiki',
#  152308: 'sistemlərindən',
#  74028: 'istifadə',
#  77970: 'kaliforniyadakı',
#  17986: 'bazadakı',
#  152268: 'sistemdən',
#  98933: 'minuteman',
#  139335: 'raketləri',
#  145419: 'sakit',
#  114638: 'okeandakı',
#  86881: 'kvajelin',
#  10012: 'atollunun',
#  145260: 'sahillərinə',
#  42456: 'düşüblər',
#  110031: 'nazirliyi',
#  139322: 'raketinin',
#  159069: 'sınaqlarının',
#  180583: 'videogörüntülərini',
#  189775: 'yayıb',
#  211224: 'şərti',
#  67997: 'hədəf',
#  25460: 'bunkerin',
#  33155: 'damını',
#  80040: 'kağız',
#  43266: 'dələndən',
#  76049: 'içəridə',
#  119823: 'partlayıb',
#  39140: 'donald',
#  168264: 'tramp',
#  28350: 'bəyan',
#  179260: 'vaşinqton',
#  140612: 'regiondakı',
#  104075: 'müttəfiqlərini',
#  132988: 'qorumaq',
#  212697: 'əlindən',
#  61850: 'gələn',
#  208548: 'şeyi',
#  180669: 'videonu',
#  75596: 'izləmək',
#  210857: 'şəklə',
#  82622: 'klikləyin',
#  65287: 'heydər',
#  20217: 'beynəlxalq',
#  1482: 'aeroportu',
#  98565: 'milyondan',
#  161671: 'sərnişinə',
#  184461: 'xidmət',
#  15747: 'bakı',
#  70743: 'ilin',
#  187375: 'yanvar',
#  149120: 'sentyabr',
#  11975: 'ayları',
#  1489: 'aeroportunun',
#  184479: 'xidmətindən',
#  179841: 'verilən',
#  58938: 'göstərici',
#  155350: 'statistikaya',
#  189320: 'yaxındır',
#  65030: 'hesabat',
#  41307: 'dövründə',
#  193382: 'yolları',
#  12634: 'azal',
#  10634: 'aviadaşıyıcısının',
#  120749: 'payına',
#  161644: 'sərnişin',
#  42455: 'düşüb',
#  113366: 'nəfəri',
#  141598: 'reyslərlə',
#  35068: 'daşınıb',
#  161663: 'sərnişinlərin',
#  50512: 'faizi',
#  141593: 'reyslərin',
#  34965: 'daşımalarının',
#  183847: 'xarici',
#  10630: 'aviadaşıyıcıların',
#  74190: 'istiqamət',
#  206967: 'üzrə',
#  10716: 'aviaşirkətə',
#  108562: 'məşhur',
#  74262: 'istiqamətlərin',
#  116022: 'onluğuna',
#  155139: 'stanbul',
#  40171: 'dubay',
#  82336: 'kiyev',
#  164904: 'tehran',
#  164784: 'tbilisi',
#  18127: 'bağdad',
#  38731: 'doha',
#  146421: 'sankt',
#  121385: 'peterburq',
#  34196: 'daxildir',
#  74271: 'istiqamətlərə',
#  177699: 'uçub',
#  1500: 'aerovağzal',
#  83894: 'kompleksi',
#  165629: 'terminal',
#  6816: 'aprel',
#  12386: 'ayında',
#  74052: 'istifadəyə',
#  179697: 'verilib',
#  206149: 'ümumi',
#  145311: 'sahəsi',
#  86867: 'kvadratmetr',
#  175069: 'təşkil',
#  41782: 'dünyada',
#  10710: 'aviaşirkətlər',
#  91008: 'limanları',
#  59033: 'göstərilən',
#  184505: 'xidmətlərin',
#  80427: 'keyfiyyətinin',
#  205333: 'öyrənilməsi',
#  75346: 'ixtisaslaşan',
#  26727: 'böyük',
#  24808: 'britaniyanın',
#  112955: 'nüfuzlu',
#  84378: 'konsaltinq',
#  209016: 'şirkəti',
#  152915: 'skytrax',
#  176045: 'ulduza',
#  90034: 'layiq',
#  58365: 'görülüb',
#  95144: 'mart',
#  204290: 'ölkələrinin',
#  7248: 'arasında',
#  162237: 'səviyyəsinə',
#  189535: 'yaxşılar',
#  152483: 'siyahısına',
#  19196: 'başçılıq',
#  183201: 'world',
#  1956: 'airport',
#  11225: 'awards',
#  103043: 'mükafatına',
#  174977: 'təzyiqin',
#  89070: 'kəskin',
#  44709: 'dəyişməsinin',
#  159858: 'səbəbləri',
#  102156: 'müalicə',
#  7935: 'arterial',
#  174968: 'təzyiq',
#  186126: 'xəstəliyi',
#  33025: 'damar',
#  152284: 'sisteminin',
#  55703: 'geniş',
#  189829: 'yayılmış',
#  186136: 'xəstəliyindən',
#  21804: 'biridir',
#  174973: 'təzyiqi',
#  33044: 'damarlarında',
#  128077: 'qanın',
#  174981: 'təzyiqinin',
#  201385: 'çoxalması',
#  187976: 'yaranan',
#  186097: 'xəstəlikdir',
#  1428: 'adətən',
#  177553: 'uzun',
#  70857: 'illər',
#  171588: 'tədricən',
#  72225: 'inkişaf',
#  120274: 'patoloji',
#  125331: 'prosesin',
#  66037: 'hiss',
#  115613: 'olunmadan',
#  49215: 'etməsi',
#  111877: 'normal',
#  124628: 'prinsipinə',
#  132301: 'qlobal',
#  174329: 'təsir',
#  114457: 'odur',
#  186138: 'xəstəliyinin',
#  102181: 'müalicəsini',
#  70787: 'ilkin',
#  107362: 'mərhələsində',
#  55333: 'gecikdirmək',
#  115377: 'olmaz',
#  102186: 'müalicəyə',
#  179088: 'vaxt',
#  93001: 'maddi',
#  172520: 'tələb',
#  115531: 'olunacaq',
#  148122: 'sayılır',
#  72395: 'insanda',
#  114903: 'olarsa',
#  65026: 'hesab',
#  112256: 'nsan',
#  205782: 'özünü',
#  174970: 'təzyiqdə',
#  109426: 'narahat',
#  45437: 'edirsə',
#  137806: 'qəhvə',
#  156276: 'stənilən',
#  88549: 'kənar',
#  174385: 'təsirlər',
#  111884: 'normaları',
#  124111: 'pozur',
#  14541: 'ağırlaşdırırlar',
#  14339: 'ağrıları',
#  25256: 'bulanması',
#  194614: 'yuxu',
#  185165: 'xroniki',
#  193729: 'yorğunlıuq',
#  152002: 'sinədə',
#  14316: 'ağrı',
#  14641: 'aşağı',
#  42402: 'düşməsi',
#  127597: 'qalxmasının',
#  212300: 'əlamətləri',
#  72411: 'insanlarda',
#  111873: 'norma',
#  58947: 'göstəriciləri',
#  174130: 'tərəfə',
#  97711: 'meyl',
#  45420: 'edirlər',
#  185465: 'xüsusiyyətlərindən',
#  9510: 'asılıdır',
#  179108: 'vaxtlar',
#  58955: 'göstəricilərində',
#  30190: 'ciddi',
#  44554: 'dəyişiklik',
#  104514: 'müşahidə',
#  45432: 'edirsinizsə',
#  116554: 'orqanizmdə',
#  109670: 'nasazlıqlardan',
#  185600: 'xəbərdar',
#  125707: 'publika',
#  117443: 'oxucuları',
#  68278: 'həlli',
#  163602: 'tanış',
#  194598: 'yuxarı',
#  42409: 'düşməsinin',
#  153552: 'somatik',
#  186106: 'xəstəlikləri',
#  33038: 'damarları',
#  54400: 'fəaliyyətinin',
#  124055: 'pozulması',
#  116884: 'osteoxondroz',
#  66574: 'hormonal',
#  124036: 'pozulma',
#  105309: 'mədəaltı',
#  182802: 'vəzi',
#  198011: 'zəifləməsi',
#  44561: 'dəyişikliklər',
#  156053: 'stress',
#  175222: 'təşviş',
#  35983: 'depressiya',
#  98980: 'miqdarda',
#  65431: 'heyvan',
#  122375: 'piylərinin',
#  74041: 'istifadəsi',
#  15898: 'balanslaşdırılmamış',
#  131750: 'qidalanma',
#  191628: 'yemək',
#  47512: 'enerji',
#  75929: 'içkiləri',
#  83024: 'kofe',
#  209471: 'şokoladın',
#  113968: 'nəzarətsiz',
#  97319: 'meteoroloji',
#  125362: 'proseslərə',
#  107564: 'məruz',
#  126959: 'qalan',
#  69087: 'həssas',
#  758: 'adamlar',
#  43826: 'dərman',
#  8044: 'artmasına',
#  3397: 'alkoqoldan',
#  67921: 'həddən',
#  44711: 'dəyişməsinə',
#  52533: 'fiziki',
#  17690: 'baxımdan',
#  195044: 'yüklənmək',
#  14517: 'ağır',
#  213366: 'əmək',
#  39873: 'doğumdan',
#  153654: 'sonrakı',
#  41233: 'dövr',
#  132283: 'qlim',
#  44569: 'dəyişikliklərindən',
#  69294: 'həyat',
#  211028: 'şəraitinə',
#  177102: 'uyğunlaşma',
#  152065: 'siqaret',
#  203279: 'çəkmək',
#  33042: 'damarların',
#  38269: 'divarlarının',
#  158903: 'süstlüyünə',
#  67911: 'həddindən',
#  196561: 'zehni',
#  62079: 'gərginlik',
#  193713: 'yorğunluq',
#  114875: 'olar',
#  111922: 'normallaşması',
#  14646: 'aşağıdakı',
#  113744: 'nəticə',
#  180263: 'verə',
#  63968: 'havada',
#  103399: 'müntəzəm',
#  122326: 'piyada',
#  62518: 'gəzinti',
#  108639: 'məşqdir',
#  97299: 'meteohəssas',
#  72406: 'insanlar',
#  124917: 'profilaktikadır',
#  193598: 'yoqa',
#  173574: 'tərbiyəsi',
#  108798: 'məşğələləri',
#  201031: 'çiqun',
#  56839: 'gimnastikası',
#  96864: 'menyudan',
#  40768: 'duzlu',
#  137116: 'qızardılmış',
#  190553: 'yağlı',
#  105770: 'məhsullarının',
#  202381: 'çıxarılması',
#  179319: 'vegetarianlıq',
#  125626: 'psixoemosional',
#  56755: 'gigiyena',
#  110742: 'nevroz',
#  35994: 'depressiyanın',
#  179147: 'vaxtında',
#  102177: 'müalicəsi',
#  125670: 'psixoterapevt',
#  102277: 'müayinəsi',
#  116538: 'orqan',
#  66583: 'hormonların',
#  76362: 'işləməsinə',
#  113939: 'nəzarət',
#  186110: 'xəstəliklərin',
#  124918: 'profilaktikası',
#  84832: 'kontrast',
#  33032: 'damarlar',
#  168568: 'trenajordur',
#  195012: 'yükləmələrdən',
#  62082: 'gərginlikdən',
#  177268: 'uzaq',
#  40436: 'durmaq',
#  3395: 'alkoqol',
#  170915: 'tütündən',
#  71306: 'imtina',
#  111937: 'normaraya',
#  145831: 'salmaq',
#  68827: 'hərdən',
#  144987: 'sadəcə',
#  156056: 'stressdən',
#  177405: 'uzaqlaşmaq',
#  74309: 'istirahət',
#  140718: 'rejiminə',
#  213471: 'əməl',
#  192858: 'yetərlidir',
#  179958: 'vermirsə',
#  166214: 'tibbi',
#  188354: 'yardım',
#  50890: 'farmakologiya',
#  124382: 'preparatlarından',
#  90147: 'lazımdır',
#  146215: 'sanatoriya',
#  86630: 'kurortlarında',
#  46959: 'eləcə',
#  43381: 'dəniz',
#  178534: 'vannaları',
#  118983: 'palçıqla',
#  206673: 'üsulları',
#  12284: 'aytən',
#  29175: 'canlı',
#  189845: 'yayımda',
#  20444: 'biabırçılıq',
#  137230: 'qızı',
#  178055: 'uşağının',
#  9703: 'atasını',
#  43522: 'dəqiqləşdirmək',
#  45729: 'efirə',
#  202276: 'çıxartdılar',
#  175986: 'ukraynada',
#  189868: 'yayımlanan',
#  1850: 'ailə',
#  105948: 'məişət',
#  124803: 'problemləri',
#  179713: 'veriliş',
#  41780: 'dünya',
#  96332: 'mediasının',
#  37811: 'diqqətini',
#  202856: 'çəkib',
#  24793: 'britaniya',
#  96327: 'mediasına',
#  74137: 'istinadla',
#  179757: 'verilişə',
#  191223: 'yaşında',
#  63299: 'hamilə',
#  127634: 'qalıb',
#  163272: 'tanya',
#  1209: 'adlı',
#  202407: 'çıxarılıb',
#  165856: 'testinin',
#  29523: 'cavabları',
#  13767: 'açıqlanacaq',
#  102547: 'müddət',
#  39796: 'doğulan',
#  137290: 'qızının',
#  132823: 'qonşunun',
#  118469: 'oğlundan',
#  36492: 'deyirdi',
#  118415: 'oğlan',
#  123243: 'polislər',
#  165841: 'test',
#  60870: 'günahsız',
#  106218: 'məlum',
#  179729: 'verilişin',
#  205166: 'ötəngünkü',
#  25774: 'buraxılışında',
#  178050: 'uşağın',
#  9704: 'atasının',
#  207023: 'üzvlərindən',
#  21871: 'birinin',
#  48963: 'etiraf',
#  163273: 'tanyanın',
#  48978: 'etirafından',
#  204001: 'ögey',
#  9696: 'atası',
#  128673: 'qardaşı',
#  45339: 'ediləcək',
#  46431: 'elan',
#  129761: 'qatılan',
#  125651: 'psixoloqlar',
#  107981: 'məsum',
#  42719: 'düşünürlər',
#  96303: 'media',
#  179716: 'verilişdə',
#  62829: 'hadisənin',
#  29135: 'canlandırılmasını',
#  192425: 'yersiz',
#  53304: 'fotoları',
#  8356: 'arvadına',
#  201042: 'çirkin',
#  36593: 'deyən',
#  211396: 'şəxsə',
#  2568: 'aktyordan',
#  59730: 'gözlənilməz',
#  170744: 'türkiyəli',
#  2565: 'aktyor',
#  91504: 'lker',
#  88261: 'kızmaz',
#  193256: 'yoldaşı',
#  9068: 'aslı',
#  88262: 'kızmazın',
#  39870: 'doğum',
#  61135: 'gününü',
#  153987: 'sosial',
#  210447: 'şəbəkə',
#  65231: 'hesabından',
#  120576: 'paylaşdığı',
#  97113: 'mesajla',
#  171147: 'təbrik',
#  98393: 'milliyet',
#  173444: 'təqibçisinin',
#  188327: 'yaraşıqlı',
#  82424: 'kişilər',
#  126752: 'qadın',
#  150080: 'sevir',
#  158003: 'sözlərinə',
#  115375: 'olmayın',
#  126799: 'qadını',
#  150216: 'sevən',
#  159789: 'səbr',
#  211074: 'şərhi',
#  179665: 'verib',
#  211077: 'şərhin',
#  53434: 'fotosunu',
#  105904: 'məhəmməd',
#  178572: 'vaqif',
#  119568: 'parlamenti',
#  54132: 'fövqəladə',
#  63149: 'halların',
#  129460: 'qarşısının',
#  4384: 'alınması',
#  17012: 'barədə',
#  127933: 'qanun',
#  90021: 'layihəsini',
#  137533: 'qəbul',
#  119571: 'parlamentində',
#  105553: 'məhdudlaşdırılması',
#  12682: 'azaldılması',
#  213400: 'əməkdaşlıq',
#  90014: 'layihəsi',
#  139711: 'ratifikasiya',
#  27094: 'bürosunun',
#  103541: 'müqəddimə',
#  93022: 'maddəlik',
#  119562: 'parlamentdə',
#  113028: 'nümayəndədən',
#  90332: 'lehinə',
#  212544: 'əleyhinə',
#  22508: 'bitərəf',
#  115286: 'olmaqla',
#  161085: 'sənədə',
#  204250: 'ölkədə',
#  63135: 'hallar',
#  171753: 'təhlükə',
#  187992: 'yarandığı',
#  63037: 'halda',
#  174074: 'tərəfin',
#  74675: 'istəyinə',
#  177049: 'uyğun',
#  174103: 'tərəflər',
#  21986: 'birlərinə',
#  97222: 'messiyə',
#  109277: 'nanilmaz',
#  172047: 'təkl',
#  10792: 'avro',
#  203967: 'ödəyirlər',
#  110966: 'ngiltərənin',
#  94403: 'mançester',
#  152354: 'siti',
#  16833: 'barselona',
#  91183: 'lionel',
#  97215: 'messinin',
#  168311: 'transferi',
#  140827: 'rekord',
#  105046: 'məbləğ',
#  203814: 'ödəməyə',
#  ...}

# %%
X_test_vectorized = vectorizer.transform(X_test)

# %%
X_test_vectorized
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 173518 stored elements and shape (2000, 216120)>

# %%
def clean_text_array(X):
    """Apply clean_text to each element in the array"""
    return np.array([clean_text(text) for text in X])

def remove_stopwords_array(X):
    """Apply remove_stopwords to each element in the array"""
    return np.array([remove_stopwords(text) for text in X])
    
    
text_pipeline = Pipeline([
    ('cleaner', FunctionTransformer(clean_text_array)),
    ('stopword_remover', FunctionTransformer(remove_stopwords_array)),
    ('vectorizer', TfidfVectorizer())
])

X = df['Title'] + df['News_Article'] 
y = df['Category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 2000, random_state=42)

X_train_vectorized = text_pipeline.fit_transform(X_train)
X_test_vectorized  = text_pipeline.transform(X_test)

# %%
def explain_model(model,  X_train, X_test, y_train, y_test, features = None):
    print('Test Results:')
    y_pred = model.predict(X_test)
    print(classification_report(y_pred, y_test))
    print(confusion_matrix(y_pred, y_test))
    
    print('Train Results:')
    y_pred_tr = model.predict(X_train)
    print(classification_report(y_pred_tr, y_train))
    print(confusion_matrix(y_pred_tr, y_train)) 
    
    print()
    print()

# %%
model = LogisticRegression()
model.fit(X_train_vectorized, y_train)
# Out:
# C:\Users\ufml\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
explain_model(model, X_train_vectorized, X_test_vectorized, y_train, y_test)
# Out:
# Test Results:
#               precision    recall  f1-score   support
#
#        Dünya       0.84      0.84      0.84       569
#      Maraqlı       0.81      0.82      0.82       620
#   Mədəniyyət       0.66      0.84      0.74        50
#      Siyasət       0.85      0.85      0.85       234
#        İdman       0.92      0.91      0.92       261
# İqtisadiyyat       0.93      0.87      0.90       266
#
#     accuracy                           0.85      2000
#    macro avg       0.84      0.86      0.84      2000
# weighted avg       0.85      0.85      0.85      2000
#
# [[479  69   3  11   3   4]
#  [ 58 511  17  11  16   7]
#  [  2   6  42   0   0   0]
#  [ 13  14   2 198   1   6]
#  [  7  15   0   1 238   0]
#  [  8  13   0  13   1 231]]
# Train Results:
#               precision    recall  f1-score   support
#
#        Dünya       0.90      0.87      0.88     13318
#      Maraqlı       0.86      0.89      0.87     14684
#   Mədəniyyət       0.69      0.93      0.79      1108
#      Siyasət       0.89      0.89      0.89      6293
#        İdman       0.97      0.92      0.94      6245
# İqtisadiyyat       0.93      0.90      0.92      6352
#
#     accuracy                           0.89     48000
#    macro avg       0.87      0.90      0.88     48000
# weighted avg       0.89      0.89      0.89     48000
#
# [[11583  1196    51   326    52   110]
#  [  900 13029   342   176    96   141]
#  [   11    31  1026    26     1    13]
#  [  147   324    50  5613    27   132]
#  [  138   315     3    22  5758     9]
#  [  128   342    11   144    12  5715]]

# %%
model2= MultinomialNB()
model2.fit(X_train_vectorized, y_train)
explain_model(model2, X_train_vectorized, X_test_vectorized, y_train, y_test)
# Out:
# Test Results:
#               precision    recall  f1-score   support
#
#        Dünya       0.79      0.76      0.77       592
#      Maraqlı       0.75      0.73      0.74       649
#   Mədəniyyət       0.17      1.00      0.29        11
#      Siyasət       0.80      0.77      0.79       242
#        İdman       0.88      0.91      0.90       251
# İqtisadiyyat       0.86      0.84      0.85       255
#
#     accuracy                           0.78      2000
#    macro avg       0.71      0.83      0.72      2000
# weighted avg       0.80      0.78      0.79      2000
#
# [[448 107   1  26   6   4]
#  [ 88 473  45  10  20  13]
#  [  0   0  11   0   0   0]
#  [ 15  14   7 187   2  17]
#  [  7  14   0   1 229   0]
#  [  9  20   0  10   2 214]]
# Train Results:
#               precision    recall  f1-score   support
#
#        Dünya       0.83      0.77      0.80     13941
#      Maraqlı       0.77      0.76      0.76     15416
#   Mədəniyyət       0.11      0.99      0.19       160
#      Siyasət       0.83      0.82      0.83      6361
#        İdman       0.92      0.91      0.92      5998
# İqtisadiyyat       0.86      0.86      0.86      6124
#
#     accuracy                           0.80     48000
#    macro avg       0.72      0.85      0.73     48000
# weighted avg       0.82      0.80      0.81     48000
#
# [[10700  2355    28   586   113   159]
#  [ 1702 11663  1116   310   287   338]
#  [    0     0   159     1     0     0]
#  [  214   370   163  5231    59   324]
#  [  130   353     4    25  5477     9]
#  [  161   496    13   154    10  5290]]

# %%
text = '''
Budapeşt, 29 dekabr, AZƏRTAC

Budapeştdə Yeni il və Dünya Azərbaycanlılarının Həmrəyliyi Günü münasibətilə bayram tədbiri keçirilib.

AZƏRTAC xəbər verir ki, Azərbaycan-Macarıstan Məzunlar Birliyinin (AHAU) təşkilatçılığı və Macarıstandakı Azərbaycan Evinin dəstəyi ilə baş tutan tədbirdə Budapeştdə yaşayan azərbaycanlı icma üzvləri bir araya gəliblər.

Tədbir Macarıstandakı Azərbaycan Evinin rəhbəri İbrahim Səfərli və Azərbaycan-Macarıstan Məzunlar Birliyinin həmtəsisçisi Günay Bayramovanın açılış nitqləri ilə başlayıb. Soydaşlarımız Dünya Azərbaycanlılarının Həmrəyliyi Günü və Yeni il münasibətilə təbrik olunub, diaspor fəaliyyətində birliyin, həmrəyliyin və birgə təşəbbüslərin əhəmiyyəti xüsusi vurğulanıb.

Qeyd edilib ki, Ümummilli Lider Heydər Əliyevin təşəbbüsü ilə təsis edilən Dünya Azərbaycanlılarının Həmrəyliyi Günü Azərbaycanın özündə və dünyanın 70-dən çox ölkəsində geniş şəkildə qeyd olunur. Bu əlamətdar gün xaricdə yaşayan həmvətənlərimiz arasında milli birlik və təşkilatlanmanın gücləndirilməsi baxımından mühüm əhəmiyyət daşıyır.

Sonda tədbir iştirakçılar arasında ünsiyyəti gücləndirən şəbəkələşmə oyunları və milli yallı rəqsi ilə xoş və səmimi ab-havada yekunlaşıb.
'''

# %%
print(model2.predict(text_pipeline.transform([text])))
# Out:
# ['Siyasət']
